# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot
import matplotlib.pyplot as plt
import numpy as np
import os
if os.name == 'posix':

    plt.rc("font", family="AppleGothic")

else:

    plt.rc("font", family="Malgun Gothic")
df = pd.read_excel('SCMre.xlsx')
df
df_nowon=df['지역(역삼동, 월계동, 여의도동, 잠실동, 종로구, 신림동, 은평동, 강서구)']=='노원구'
df_gangnam=df['지역(역삼동, 월계동, 여의도동, 잠실동, 종로구, 신림동, 은평동, 강서구)']=='강남구'
df.rename(columns={'지역(역삼동, 월계동, 여의도동, 잠실동, 종로구, 신림동, 은평동, 강서구)':'지역'}, inplace=True)
df
a=df[df_nowon]
b=df[df_gangnam]
#condition1 = (chinese.업종 == "숙박")
#df_nowon=df['지역(역삼동, 월계동, 여의도동, 잠실동, 종로구, 신림동, 은평동, 강서구)']=='노원구'
df_nowon=(df.지역=='노원구')
df_gangnam=(df.지역=='강남구')
#df_nowon=df['지역(역삼동, 월계동, 여의도동, 잠실동, 종로구, 신림동, 은평동, 강서구)']=='노원구'
#df_gangnam=df['지역(역삼동, 월계동, 여의도동, 잠실동, 종로구, 신림동, 은평동, 강서구)']=='강남구'
#print(df_nowon)
a
b
# Out:
#              차량 이름 이용중인지(o,x)  차량 이용 가격   시간대   지역  주차장에서 이용중인 차 개수  \
# 55          디 올뉴투싼          X   10000.0   9.0  강남구             10.0
# 56            더뉴K3          X   10000.0   9.0  강남구             10.0
# 57            더뉴레이          X   10000.0   9.0  강남구             10.0
# 58             셀토스          X   10000.0   9.0  강남구             10.0
# 59           올뉴아반떼          X   10000.0   9.0  강남구             10.0
# ...            ...        ...       ...   ...  ...              ...
# 1829  2021 쏘렌토 7인승          O   36380.0  22.0  강남구             17.0
# 1830      지프 레니게이드          O   32740.0  22.0  강남구             17.0
# 1831         미니클럽맨          O   32740.0  22.0  강남구             17.0
# 1832       2021 K5          O   31070.0  22.0  강남구             17.0
# 1833     아이오닉 일렉트릭          O   27570.0  22.0  강남구             17.0
#
#       주차장 내 차 개수             주차장 이름  km당 가격(최대)  주차장_이용률
# 55          16.0  현대백화점 무역센터점 별관주차장       220.0  0.62500
# 56          16.0  현대백화점 무역센터점 별관주차장       200.0  0.62500
# 57          16.0  현대백화점 무역센터점 별관주차장       190.0  0.62500
# 58          16.0  현대백화점 무역센터점 별관주차장       210.0  0.62500
# 59          16.0  현대백화점 무역센터점 별관주차장       200.0  0.62500
# ...          ...                ...         ...      ...
# 1829        23.0          코엑스 옥상주차장       250.0  0.73913
# 1830        23.0          코엑스 옥상주차장       240.0  0.73913
# 1831        23.0          코엑스 옥상주차장       250.0  0.73913
# 1832        23.0          코엑스 옥상주차장       210.0  0.73913
# 1833        23.0          코엑스 옥상주차장        50.0  0.73913
#
# [928 rows x 10 columns]

# %%
gang_9=(b['시간대']==18.0 )
gang9=b[gang_9]
gang99=(gang9['이용중인지(o,x)']=='O')
gang9use=gang9[gang99]
tusan=(gang9use['차량 이름']=='디 올뉴투싼')
tg=gang9use[tusan]
utg=tg['주차장에서 이용중인 차 개수'].sum()
gang_9=(b['시간대']==18.0 )
gang9=b[gang_9]
gang_x9=(gang9['이용중인지(o,x)']=='X')
gang9nouse=gang9[gang_x9]
tusan=(gang9nouse['차량 이름']=='디 올뉴투싼')
tg=gang9nouse[tusan]
ntg=tg['주차장에서 이용중인 차 개수'].sum()
(utg)/(ntg+utg)
# Out:
# 0.35135135135135137

# %%
length=gang9['차량 이름'].unique()
length
# Out:
# array(['디 올뉴투싼', '더뉴K3', '더뉴레이', '셀토스', '올뉴아반떼', '더뉴아반떼', '캐스퍼', 'G80',
#        '벤츠 C200', '더뉴그렌저', '아이오닉5', '지프 레니게이드', '미니클럽맨', '2021 K5', '제타',
#        '디 올뉴스포티지', '디 올뉴스포피지', '모닝어반', '코나', '더뉴코나', 'K8',
#        '카니발 프레스티지 9인승', '2021 쏘렌토 7인승', '아이오닉 일렉트릭', '올뉴K3', '올뉴모닝',
#        '쏘나타 DN8', '아이오닉 EV', '코나EV', '밴츠 C200', '쏘나타 뉴라이즈', '스포티지 더볼드',
#        '싼타페', '볼트EV'], dtype=object)

# %%
df1 =pd.DataFrame()
my_list=length
for i in range(len(my_list)):
    tusan=(gang9use['차량 이름']==my_list[i])
    tg=gang9use[tusan]
    utg=tg['주차장에서 이용중인 차 개수'].sum()
    tusan=(gang9nouse['차량 이름']==my_list[i])
    tg=gang9nouse[tusan]
    ntg=tg['주차장에서 이용중인 차 개수'].sum()
    ratio=(utg)/(ntg+utg)
    df1 = df1.append(pd.DataFrame([[ratio]], columns=['count']), ignore_index=True)
#print(ratio)    
df1
df1.insert(0,'차종',length)
df1
# Out:
#                차종     count
# 0          디 올뉴투싼  0.351351
# 1            더뉴K3  0.140351
# 2            더뉴레이  0.367347
# 3             셀토스  0.593750
# 4           올뉴아반떼  0.195402
# 5           더뉴아반떼  0.302326
# 6             캐스퍼  0.509804
# 7             G80  1.000000
# 8         벤츠 C200  1.000000
# 9           더뉴그렌저  1.000000
# 10          아이오닉5  1.000000
# 11       지프 레니게이드  1.000000
# 12          미니클럽맨  1.000000
# 13        2021 K5  0.973333
# 14             제타  0.774194
# 15       디 올뉴스포티지  0.833333
# 16       디 올뉴스포피지  0.000000
# 17           모닝어반  0.250000
# 18             코나  0.481481
# 19           더뉴코나  1.000000
# 20             K8  1.000000
# 21  카니발 프레스티지 9인승  1.000000
# 22   2021 쏘렌토 7인승  1.000000
# 23      아이오닉 일렉트릭  1.000000
# 24           올뉴K3  1.000000
# 25           올뉴모닝  0.000000
# 26        쏘나타 DN8  1.000000
# 27        아이오닉 EV  1.000000
# 28           코나EV  1.000000
# 29        밴츠 C200  1.000000
# 30       쏘나타 뉴라이즈  1.000000
# 31       스포티지 더볼드  0.000000
# 32            싼타페  1.000000
# 33           볼트EV  1.000000

# %%
nowon_9=(a['시간대']==18.0 )
nowon9=a[nowon_9]
nowon99=(nowon9['이용중인지(o,x)']=='O')
nowon9use=nowon9[nowon99]
t=(nowon9use['차량 이름']=='디 올뉴투싼')
t_g=nowon9use[t]
u_tg=t_g['주차장에서 이용중인 차 개수'].sum()
nowon_9=(a['시간대']==18.0 )
nowon9=a[nowon_9]
nowon_x9=(nowon9['이용중인지(o,x)']=='X')
nowon9nouse=nowon9[nowon_x9]
t=(nowon9nouse['차량 이름']=='디 올뉴투싼')
t_g=nowon9nouse[t]
n_tg=t_g['주차장에서 이용중인 차 개수'].sum()
(u_tg)/(n_tg+u_tg)
length1=nowon9['차량 이름'].unique()
length1
df_ =pd.DataFrame()
my_list=length1
for i in range(len(my_list)):
    t=(nowon9use['차량 이름']==my_list[i])
    t_g=nowon9use[t]
    u_tg=t_g['주차장에서 이용중인 차 개수'].sum()
    t=(nowon9nouse['차량 이름']==my_list[i])
    t_g=nowon9nouse[t]
    n_tg=t_g['주차장에서 이용중인 차 개수'].sum()
    ratio=(u_tg)/(n_tg+u_tg)
    df_ = df_.append(pd.DataFrame([[ratio]], columns=['count']), ignore_index=True)
#print(ratio)    
df_
df_.insert(0,'차종',length1)
df_
# Out:
# <ipython-input-6-59b0bc8c35a2>:27: RuntimeWarning: invalid value encountered in double_scalars
#   ratio=(u_tg)/(n_tg+u_tg)
#                차종     count
# 0             셀토스  0.734043
# 1           올뉴아반떼  0.862500
# 2            더뉴K3  0.314286
# 3              코나  0.692308
# 4        디 올뉴스포티지  0.304348
# 5          디 올뉴투싼  0.304348
# 6           더뉴아반떼  0.800000
# 7            올뉴K3  0.590909
# 8        스포티지 더볼드  0.413793
# 9           더뉴그렌저  1.000000
# 10          아이오닉5  1.000000
# 11  카니발 프레스티지 9인승  1.000000
# 12        2021 K5  1.000000
# 13            캐스퍼  1.000000
# 14           올뉴모닝  0.777778
# 15           볼트EV  1.000000
# 16           더뉴레이  0.750000
# 17          올뉴모닝        NaN
# 18           모닝어반  0.678571
# 19      아이오닉 일렉트릭  1.000000
# 20        아이오닉 EV  1.000000
# 21        쏘나타 DN8  1.000000

# %%
x=df1['차종']
y=df1['count']
plt.bar(x,y)
# Out:
# <BarContainer object of 34 artists>

# %%
x=df_['차종']
y=df_['count']
plt.bar(x,y)
# Out:
# <BarContainer object of 22 artists>

# %%
df_.to_csv('n18.csv')
n18 = pd.read_csv('n18.csv')

df_=n18.sort_values('count',axis=0,ascending=False)
df_
x=df_['차종']
y=df_['count']

plt.bar(x,y)
plt.xticks(rotation=75)
plt.title('노원 18시')
# Out:
# Text(0.5, 1.0, '노원 18시')

# %%
df1.to_csv('g18.csv')
g18 = pd.read_csv('g18.csv')

df1=g18.sort_values('count',axis=0,ascending=False)
df1
x=df1['차종']
y=df1['count']

plt.bar(x,y)
plt.xticks(rotation=75)
plt.title('강남 18시')
# Out:
# Text(0.5, 1.0, '강남 18시')
