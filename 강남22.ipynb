# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot
import matplotlib.pyplot as plt
import numpy as np
import os
if os.name == 'posix':

    plt.rc("font", family="AppleGothic")

else:

    plt.rc("font", family="Malgun Gothic")
df = pd.read_excel('SCMre.xlsx')
df
df_nowon=df['지역(역삼동, 월계동, 여의도동, 잠실동, 종로구, 신림동, 은평동, 강서구)']=='노원구'
df_gangnam=df['지역(역삼동, 월계동, 여의도동, 잠실동, 종로구, 신림동, 은평동, 강서구)']=='강남구'
df.rename(columns={'지역(역삼동, 월계동, 여의도동, 잠실동, 종로구, 신림동, 은평동, 강서구)':'지역'}, inplace=True)
df
a=df[df_nowon]
b=df[df_gangnam]
#condition1 = (chinese.업종 == "숙박")
#df_nowon=df['지역(역삼동, 월계동, 여의도동, 잠실동, 종로구, 신림동, 은평동, 강서구)']=='노원구'
df_nowon=(df.지역=='노원구')
df_gangnam=(df.지역=='강남구')
#df_nowon=df['지역(역삼동, 월계동, 여의도동, 잠실동, 종로구, 신림동, 은평동, 강서구)']=='노원구'
#df_gangnam=df['지역(역삼동, 월계동, 여의도동, 잠실동, 종로구, 신림동, 은평동, 강서구)']=='강남구'
#print(df_nowon)
a
b
# Out:
#              차량 이름 이용중인지(o,x)  차량 이용 가격   시간대   지역  주차장에서 이용중인 차 개수  \
# 55          디 올뉴투싼          X   10000.0   9.0  강남구             10.0
# 56            더뉴K3          X   10000.0   9.0  강남구             10.0
# 57            더뉴레이          X   10000.0   9.0  강남구             10.0
# 58             셀토스          X   10000.0   9.0  강남구             10.0
# 59           올뉴아반떼          X   10000.0   9.0  강남구             10.0
# ...            ...        ...       ...   ...  ...              ...
# 1829  2021 쏘렌토 7인승          O   36380.0  22.0  강남구             17.0
# 1830      지프 레니게이드          O   32740.0  22.0  강남구             17.0
# 1831         미니클럽맨          O   32740.0  22.0  강남구             17.0
# 1832       2021 K5          O   31070.0  22.0  강남구             17.0
# 1833     아이오닉 일렉트릭          O   27570.0  22.0  강남구             17.0
#
#       주차장 내 차 개수             주차장 이름  km당 가격(최대)  주차장_이용률
# 55          16.0  현대백화점 무역센터점 별관주차장       220.0  0.62500
# 56          16.0  현대백화점 무역센터점 별관주차장       200.0  0.62500
# 57          16.0  현대백화점 무역센터점 별관주차장       190.0  0.62500
# 58          16.0  현대백화점 무역센터점 별관주차장       210.0  0.62500
# 59          16.0  현대백화점 무역센터점 별관주차장       200.0  0.62500
# ...          ...                ...         ...      ...
# 1829        23.0          코엑스 옥상주차장       250.0  0.73913
# 1830        23.0          코엑스 옥상주차장       240.0  0.73913
# 1831        23.0          코엑스 옥상주차장       250.0  0.73913
# 1832        23.0          코엑스 옥상주차장       210.0  0.73913
# 1833        23.0          코엑스 옥상주차장        50.0  0.73913
#
# [928 rows x 10 columns]

# %%
gang_9=(b['시간대']==22.0 )
gang9=b[gang_9]
gang99=(gang9['이용중인지(o,x)']=='O')
gang9use=gang9[gang99]
tusan=(gang9use['차량 이름']=='디 올뉴투싼')
tg=gang9use[tusan]
utg=tg['주차장에서 이용중인 차 개수'].sum()
gang_9=(b['시간대']==22.0 )
gang9=b[gang_9]
gang_x9=(gang9['이용중인지(o,x)']=='X')
gang9nouse=gang9[gang_x9]
tusan=(gang9nouse['차량 이름']=='디 올뉴투싼')
tg=gang9nouse[tusan]
ntg=tg['주차장에서 이용중인 차 개수'].sum()
(utg)/(ntg+utg)
# Out:
# 0.7241379310344828

# %%
length=gang9['차량 이름'].unique()
length
# Out:
# array(['더뉴아반떼', '2021 K5', '올뉴아반떼', '디 올뉴투싼', '더뉴레이', '셀토스', '더뉴K3', '코나',
#        '미니클럽맨', '볼트EV', '더뉴그렌저', '아이오닉5', '올뉴모닝', '2021 쏘렌토 7인승', '캐스퍼',
#        '더뉴코나', '싼타페', '디 올뉴스포티지', '아이오닉 EV', '카니발 프레스티지 9인승', '스포티지 더볼드',
#        '카니발 프레스티지 11인승', '쏘나타 DN8', '제타', '쏘나타 뉴라이즈', '지프 레니게이드', '모닝어반',
#        '쏘렌토', 'G80', '벤츠 C200', '올뉴K3', 'K8', '아이오닉 일렉트릭'], dtype=object)

# %%
df1 =pd.DataFrame()
my_list=length
for i in range(len(my_list)):
    tusan=(gang9use['차량 이름']==my_list[i])
    tg=gang9use[tusan]
    utg=tg['주차장에서 이용중인 차 개수'].sum()
    tusan=(gang9nouse['차량 이름']==my_list[i])
    tg=gang9nouse[tusan]
    ntg=tg['주차장에서 이용중인 차 개수'].sum()
    ratio=(utg)/(ntg+utg)
    df1 = df1.append(pd.DataFrame([[ratio]], columns=['count']), ignore_index=True)
#print(ratio)    
df1
df1.insert(0,'차종',length)
df1
# Out:
#                 차종     count
# 0            더뉴아반떼  0.274510
# 1          2021 K5  1.000000
# 2            올뉴아반떼  0.506667
# 3           디 올뉴투싼  0.724138
# 4             더뉴레이  0.548387
# 5              셀토스  0.487805
# 6             더뉴K3  0.232143
# 7               코나  0.250000
# 8            미니클럽맨  1.000000
# 9             볼트EV  1.000000
# 10           더뉴그렌저  1.000000
# 11           아이오닉5  1.000000
# 12            올뉴모닝  0.600000
# 13    2021 쏘렌토 7인승  1.000000
# 14             캐스퍼  0.105263
# 15            더뉴코나  0.653846
# 16             싼타페  1.000000
# 17        디 올뉴스포티지  0.928571
# 18         아이오닉 EV  1.000000
# 19   카니발 프레스티지 9인승  1.000000
# 20        스포티지 더볼드  0.000000
# 21  카니발 프레스티지 11인승  1.000000
# 22         쏘나타 DN8  1.000000
# 23              제타  0.678571
# 24        쏘나타 뉴라이즈  1.000000
# 25        지프 레니게이드  1.000000
# 26            모닝어반  0.291667
# 27             쏘렌토  1.000000
# 28             G80  1.000000
# 29         벤츠 C200  1.000000
# 30            올뉴K3  0.000000
# 31              K8  1.000000
# 32       아이오닉 일렉트릭  1.000000

# %%
nowon_9=(a['시간대']==22.0 )
nowon9=a[nowon_9]
nowon99=(nowon9['이용중인지(o,x)']=='O')
nowon9use=nowon9[nowon99]
t=(nowon9use['차량 이름']=='디 올뉴투싼')
t_g=nowon9use[t]
u_tg=t_g['주차장에서 이용중인 차 개수'].sum()
nowon_9=(a['시간대']==22.0 )
nowon9=a[nowon_9]
nowon_x9=(nowon9['이용중인지(o,x)']=='X')
nowon9nouse=nowon9[nowon_x9]
t=(nowon9nouse['차량 이름']=='디 올뉴투싼')
t_g=nowon9nouse[t]
n_tg=t_g['주차장에서 이용중인 차 개수'].sum()
(u_tg)/(n_tg+u_tg)
length1=nowon9['차량 이름'].unique()
length1
df_ =pd.DataFrame()
my_list=length1
for i in range(len(my_list)):
    t=(nowon9use['차량 이름']==my_list[i])
    t_g=nowon9use[t]
    u_tg=t_g['주차장에서 이용중인 차 개수'].sum()
    t=(nowon9nouse['차량 이름']==my_list[i])
    t_g=nowon9nouse[t]
    n_tg=t_g['주차장에서 이용중인 차 개수'].sum()
    ratio=(u_tg)/(n_tg+u_tg)
    df_ = df_.append(pd.DataFrame([[ratio]], columns=['count']), ignore_index=True)
#print(ratio)    
df_
df_.insert(0,'차종',length1)
df_
# Out:
#                차종     count
# 0             셀토스  0.475610
# 1           올뉴아반떼  0.637500
# 2              코나  0.818182
# 3            더뉴레이  0.529412
# 4            더뉴K3  0.625000
# 5             캐스퍼  0.500000
# 6          디 올뉴투싼  0.527273
# 7            모닝어반  0.363636
# 8        스포티지 더볼드  0.365385
# 9         2021 K5  1.000000
# 10       디 올뉴스포티지  0.734694
# 11          더뉴아반떼  0.709091
# 12           올뉴K3  0.863636
# 13          더뉴그렌저  1.000000
# 14          아이오닉5  1.000000
# 15  카니발 프레스티지 9인승  1.000000
# 16           올뉴모닝  0.800000
# 17           볼트EV  1.000000
# 18        아이오닉 EV  1.000000
# 19        쏘나타 DN8  1.000000
# 20      아이오닉 일렉트릭  1.000000
# 21           더뉴코나  1.000000

# %%
x=df1['차종']
y=df1['count']
plt.bar(x,y)
# Out:
# <BarContainer object of 33 artists>

# %%
x=df_['차종']
y=df_['count']
plt.bar(x,y)
# Out:
# <BarContainer object of 22 artists>

# %%
df1.to_csv('g22.csv')
g22 = pd.read_csv('g22.csv')

df1=g22.sort_values('count',axis=0,ascending=False)
df1
x=df1['차종']
y=df1['count']

plt.bar(x,y)
plt.xticks(rotation=75)
plt.title('강남 22시')
# Out:
# Text(0.5, 1.0, '강남 22시')

# %%
df_.to_csv('n22.csv')
n22 = pd.read_csv('n22.csv')

df_=n22.sort_values('count',axis=0,ascending=False)
df_
x=df_['차종']
y=df_['count']

plt.bar(x,y)
plt.xticks(rotation=75)
plt.title('노원 22시')
# Out:
# Text(0.5, 1.0, '노원 22시')
