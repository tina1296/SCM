# %%
import numpy as np
import pandas as pd
from openpyxl import load_workbook

car = load_workbook("SCMre.xlsx", data_only=True)
ws=car['시트1']
data=ws.values
columns=next(data)[0:]
df=pd.DataFrame(data,columns=columns)
df.head()
print(len(df))


df= df.dropna(axis=0)#nan 값제거
print(len(df))
df.head()
car
# Out:
# 1834
# 0

# %%
df_nowon=df['지역(역삼동, 월계동, 여의도동, 잠실동, 종로구, 신림동, 은평동, 강서구)']=='노원구'
df_gangnam=df['지역(역삼동, 월계동, 여의도동, 잠실동, 종로구, 신림동, 은평동, 강서구)']=='강남구'
df.rename(columns={'지역(역삼동, 월계동, 여의도동, 잠실동, 종로구, 신림동, 은평동, 강서구)':'지역'}, inplace=True)
df
a=df[df_nowon]
b=df[df_gangnam]
#condition1 = (chinese.업종 == "숙박")
#df_nowon=df['지역(역삼동, 월계동, 여의도동, 잠실동, 종로구, 신림동, 은평동, 강서구)']=='노원구'
df_nowon=(df.지역=='노원구')
df_gangnam=(df.지역=='강남구')
#df_nowon=df['지역(역삼동, 월계동, 여의도동, 잠실동, 종로구, 신림동, 은평동, 강서구)']=='노원구'
#df_gangnam=df['지역(역삼동, 월계동, 여의도동, 잠실동, 종로구, 신림동, 은평동, 강서구)']=='강남구'
#print(df_nowon)
a
b
# Out:
# Empty DataFrame
# Columns: [차량 이름, 이용중인지(o,x), 차량 이용 가격, 시간대, 지역, 주차장에서 이용중인 차 개수, 주차장 내 차 개수, 주차장 이름, km당 가격(최대), 주차장_이용률, None, None, None]
# Index: []

# %%
a['주차장_이용률']=a['주차장에서 이용중인 차 개수']/a['주차장 내 차 개수']
b['주차장_이용률']=b['주차장에서 이용중인 차 개수']/b['주차장 내 차 개수']

b
# Out:
# <ipython-input-18-e9c4dcc26503>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['주차장_이용률']=a['주차장에서 이용중인 차 개수']/a['주차장 내 차 개수']
# <ipython-input-18-e9c4dcc26503>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b['주차장_이용률']=b['주차장에서 이용중인 차 개수']/b['주차장 내 차 개수']
#              차량 이름 이용중인지(o,x)  차량 이용 가격   시간대   지역  주차장에서 이용중인 차 개수  \
# 55          디 올뉴투싼          X   10000.0   9.0  강남구             10.0
# 56            더뉴K3          X   10000.0   9.0  강남구             10.0
# ...

# %%
a
# Out:
#               차량 이름 이용중인지(o,x)  차량 이용 가격   시간대   지역  주차장에서 이용중인 차 개수  \
# 0               셀토스          X   10000.0   9.0  노원구              4.0
# 1             올뉴아반떼          O   10000.0   9.0  노원구              4.0
# 2                코나          X   10000.0   9.0  노원구              4.0
# 3              더뉴레이          X    8970.0   9.0  노원구              4.0
# 4              더뉴K3          O   10000.0   9.0  노원구              4.0
# ...             ...        ...       ...   ...  ...              ...
# 1790  카니발 프레스티지 9인승          O   68010.0  22.0  노원구             11.0
# 1791         더뉴 그렌저          O   65330.0  22.0  노원구             11.0
# 1792        2021 K5          O   53750.0  22.0  노원구             11.0
# 1793           올뉴K3          O   10000.0  22.0  노원구             11.0
# 1794       스포티지 더볼드          O   10000.0  22.0  노원구             11.0
#
#       주차장 내 차 개수    주차장 이름  km당 가격(최대)   주차장_이용률
# 0            7.0  광운대역 주차장       210.0  0.571429
# ...

# %%
a_nowon=a.drop_duplicates(['차량 이름'])
a_nowon
a_nowonn=np.array(a_nowon['차량 이름'].tolist())

# %%
a_nowonn
# Out:
# array(['셀토스', '올뉴아반떼', '코나', '더뉴레이', '더뉴K3', '캐스퍼', '디 올뉴투싼', '모닝 어반',
#        '스포티지 더볼드', '2021 K5', '더뉴 K3', '올뉴모닝', '더뉴아반떼', '아이오닉5',
#        '지프 레니게이드', '볼트EV', '디 올뉴스포티지', '올뉴K3', '더뉴그랜저', '카니발 프레스티지 9인승',
#        '올뉴모닝 ', '모닝어반', '아이오닉 일렉트릭', '아이오닉EV', '쏘나타DN8', '아이오익5',
#        '쏘나타DNB', '더뉴코나'], dtype='<U13')

# %%
b_gangnamm=b.drop_duplicates(['차량 이름'])
b_gangnam=np.array(b_gangnamm['차량 이름'].tolist())

# %%
b_gangnam
# Out:
# array(['디 올뉴투싼', '더뉴K3', '더뉴레이', '셀토스', '올뉴아반떼', '캐스퍼', 'G80', '벤츠 C200',
#        '더뉴그랜저', '아이오닉5', '지프 레니게이드', '미니클럽맨', '2021 K5', '제타', '디 올뉴스포티지',
#        '더뉴아반떼', '더뉴코나', '더뉴 K3', '모닝 어반', '코나', '올뉴K3', 'K8',
#        '카니발 프레스티지 9인승', '2021 쏘렌토 7인승', '아이오닉 일렉트릭', '디 올뉴스포피지', '볼트EV',
#        '올뉴모닝', '싼타페', '쏘나타DN8', '스포티지 더볼드', '쏘렌토', '아이오닉EV', '모닝어반',
#        '아이오닉 EV', '코나EV', '밴츠 C200', '쏘나타 뉴라이즈', '더뉴 그렌저',
#        '카니발 프레스티지 11인승', '셀토스 ', '더뉴아반뗴', '스포티즈 더볼드', '더뉴그렌저', '코나 EV',
#        '올뉴이반떼', '쏘나타 DN8', '디올뉴투싼'], dtype='<U14')

# %%
import numpy as np
import pandas as pd
df = pd.read_excel('SCMre.xlsx')

# %%
df
# Out:
#              차량 이름 이용중인지(o,x)  차량 이용 가격   시간대  \
# 0              셀토스          X   10000.0   9.0
# 1            올뉴아반떼          O   10000.0   9.0
# 2               코나          X   10000.0   9.0
# 3             더뉴레이          X    8970.0   9.0
# 4             더뉴K3          O   10000.0   9.0
# ...            ...        ...       ...   ...
# 1829  2021 쏘렌토 7인승          O   36380.0  22.0
# 1830      지프 레니게이드          O   32740.0  22.0
# 1831         미니클럽맨          O   32740.0  22.0
# 1832       2021 K5          O   31070.0  22.0
# 1833     아이오닉 일렉트릭          O   27570.0  22.0
#
#      지역(역삼동, 월계동, 여의도동, 잠실동, 종로구, 신림동, 은평동, 강서구)  주차장에서 이용중인 차 개수  주차장 내 차 개수  \
# 0                                            노원구              4.0         7.0
# 1                                            노원구              4.0         7.0
# 2                                            노원구              4.0         7.0
# 3                                            노원구              4.0         7.0
# ...

# %%
cardata.rename(columns={'지역(역삼동, 월계동, 여의도동, 잠실동, 종로구, 신림동, 은평동, 강서구)':'지역'}, inplace=True)
cardata
df_nowon=(df.지역=='노원구')
df_gangnam=(df.지역=='강남구')
a=cardata[df_nowon]
#b=cardata[df_gangnam]
# Out:
# <ipython-input-10-9e5e63ec009d>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   a=cardata[df_nowon]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-10-9e5e63ec009d> in <module>
#       3 df_nowon=(df.지역=='노원구')
#       4 df_gangnam=(df.지역=='강남구')
# ----> 5 a=cardata[df_nowon]
#       6 #b=cardata[df_gangnam]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2891         # Do we have a (boolean) 1d indexer?
#    2892         if com.is_bool_indexer(key):
# -> 2893             return self._getitem_bool_array(key)
#    2894
#    2895         # We are left with two options: a single key, and a collection of keys,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
# ...

# %%
import numpy as np
import pandas as pd
from openpyxl import load_workbook

car = load_workbook("SCM1.xlsx", data_only=True)
ws=car['시트1']
data=ws.values
columns=next(data)[0:]
df=pd.DataFrame(data,columns=columns)
df.head()
print(len(df))


df= df.dropna(axis=0)#nan 값제거
print(len(df))
df.head()
df
# Out:
# 1919
# 1832
#              차량 이름 이용중인지(o,x)  차량 이용 가격   시간대  \
# 0              셀토스          X   10000.0   9.0
# 1            올뉴아반떼          O   10000.0   9.0
# 2               코나          X   10000.0   9.0
# 3             더뉴레이          X    8970.0   9.0
# 4             더뉴K3          O   10000.0   9.0
# ...            ...        ...       ...   ...
# 1848  2021 쏘렌토 7인승          O   38980.0  22.0
# 1849      지프 레니게이드          O   38120.0  22.0
# 1850         미니클럽맨          O   34300.0  22.0
# 1851       2021 K5          O   32550.0  22.0
# 1852     아이오닉 일렉트릭          O   28880.0  22.0
#
#      지역(역삼동, 월계동, 여의도동, 잠실동, 종로구, 신림동, 은평동, 강서구)  주차장에서 이용중인 차 개수  주차장 내 차 개수  \
# 0                                            노원구              4.0         7.0
# 1                                            노원구              4.0         7.0
# 2                                            노원구              4.0         7.0
# 3                                            노원구              4.0         7.0
# ...

# %%
df_nowon=(df.지역=='노원구')
df_gangnam=(df.지역=='강남구')
nowon=cardata[df_nowon]
gangnam=cardata[df_gangnam]
nowon
gangnam
# Out:
# <ipython-input-12-8f966b240a10>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   nowon=cardata[df_nowon]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-12-8f966b240a10> in <module>
#       1 df_nowon=(df.지역=='노원구')
#       2 df_gangnam=(df.지역=='강남구')
# ----> 3 nowon=cardata[df_nowon]
#       4 gangnam=cardata[df_gangnam]
#       5 nowon
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2891         # Do we have a (boolean) 1d indexer?
#    2892         if com.is_bool_indexer(key):
# -> 2893             return self._getitem_bool_array(key)
#    2894
#    2895         # We are left with two options: a single key, and a collection of keys,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
# ...

# %%
df1=nowon

# %%
nowon_9=(df1['시간대']==9.0)
nowon9=df1[nowon_9]
#nowon_12=(df1['시간대']==12.0)
#nowon_18=(df1['시간대']==18.0)
#nowon_22=(df1['시간대']==22.0)
'''
nowon9=df[nowon_9]
nowon12=df[nowon_12]
nowon18=df[nowon_18]
nowon22=df[nowon_22]
'''
nowon_9
# Out:
# 319     False
# 320     False
# 321     False
# 322     False
# 323     False
#         ...
# 1848    False
# 1849    False
# 1850    False
# 1851    False
# 1852    False
# Name: 시간대, Length: 440, dtype: bool

# %%
nowon9
# Out:
#        차량 이름 이용중인지(o,x)  차량 이용 가격  시간대   지역  주차장에서 이용중인 차 개수  주차장 내 차 개수  \
# 0        셀토스          X   10000.0  9.0  노원구              4.0         7.0
# 1      올뉴아반떼          O   10000.0  9.0  노원구              4.0         7.0
# 2         코나          X   10000.0  9.0  노원구              4.0         7.0
# 3       더뉴레이          X    8970.0  9.0  노원구              4.0         7.0
# 4       더뉴K3          O   10000.0  9.0  노원구              4.0         7.0
# ...      ...        ...       ...  ...  ...              ...         ...
# 1686   올뉴아반떼          O   10000.0  9.0  강남구              2.0         2.0
# 1687     셀토스          X   10000.0  9.0  강남구              1.0         4.0
# 1688     캐스퍼          O   10000.0  9.0  강남구              1.0         4.0
# 1689  더뉴 그렌저          O   57730.0  9.0  강남구              1.0         4.0
# 1690    볼트EV          O   46920.0  9.0  강남구              1.0         4.0
#
#         주차장 이름  km당 가격(최대)   주차장_이용률
# 0     광운대역 주차장       210.0  0.571429
# ...

# %%
import matplotlib.pyplot as plot
import matplotlib.pyplot as plt
import numpy as np
import os
if os.name == 'posix':

    plt.rc("font", family="AppleGothic")

else:

    plt.rc("font", family="Malgun Gothic")
CountStatus9 = pd.value_counts(nowon9['차량 이름'].values, sort=True) 
CountStatus9.plot.bar() 
CountStatus9.plot.bar(grid=True, figsize=(10,8), fontsize=15) # figsize, fontsize 조정
CountStatus12 = pd.value_counts(nowon12['차량 이름'].values, sort=True) 
CountStatus12.plot.bar() 
CountStatus12.plot.bar(grid=True, figsize=(10,8), fontsize=15)
CountStatus18 = pd.value_counts(nowon12['차량 이름'].values, sort=True) 
CountStatus18.plot.bar() 
CountStatus18.plot.bar(grid=True, figsize=(10,8), fontsize=15)
CountStatus22 = pd.value_counts(nowon12['차량 이름'].values, sort=True) 
CountStatus22.plot.bar() 
CountStatus22.plot.bar(grid=True, figsize=(10,8), fontsize=15)
# Out:
# <AxesSubplot:>

# %%
my_list=[nowon9,nowon12,nowon18,nowon22]
for i in range(len(my_list)):
    CountStatus = pd.value_counts(my_list[i]['차량 이름'].values, sort=True)
    CountStatus.plot.bar() 
    CountStatus.plot.bar(grid=True, figsize=(10,8), fontsize=15) # figsize, fontsize 조정

# %%
nowon=df[df_nowon]
df_nowon=(df.지역=='노원구')
dfnowon=nowon[df_nowon]
dfnowon

# %%
dfnowon=nowon[df_nowon]
dfnowon
# Out:
# <ipython-input-60-68f649be9c1b>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfnowon=nowon[df_nowon]
#               차량 이름 이용중인지(o,x)  차량 이용 가격   시간대   지역  주차장에서 이용중인 차 개수  \
# 0               셀토스          X   10000.0   9.0  노원구              4.0
# 1             올뉴아반떼          O   10000.0   9.0  노원구              4.0
# 2                코나          X   10000.0   9.0  노원구              4.0
# 3              더뉴레이          X    8970.0   9.0  노원구              4.0
# 4              더뉴K3          O   10000.0   9.0  노원구              4.0
# ...             ...        ...       ...   ...  ...              ...
# 1809  카니발 프레스티지 9인승          O   68010.0  22.0  노원구             11.0
# 1810         더뉴 그렌저          O   65330.0  22.0  노원구             11.0
# 1811        2021 K5          O   53750.0  22.0  노원구             11.0
# 1812           올뉴K3          O   10000.0  22.0  노원구             11.0
# 1813       스포티지 더볼드          O   10000.0  22.0  노원구             11.0
#
# ...

# %%
nowon_9=(a['시간대']==9.0)
nowon9=a[nowon_9]

# %%
nowon9
# Out:
#       차량 이름 이용중인지(o,x)  차량 이용 가격  시간대   지역  주차장에서 이용중인 차 개수  주차장 내 차 개수  \
# 0       셀토스          X   10000.0  9.0  노원구              4.0         7.0
# 1     올뉴아반떼          O   10000.0  9.0  노원구              4.0         7.0
# 2        코나          X   10000.0  9.0  노원구              4.0         7.0
# 3      더뉴레이          X    8970.0  9.0  노원구              4.0         7.0
# 4      더뉴K3          O   10000.0  9.0  노원구              4.0         7.0
# ...     ...        ...       ...  ...  ...              ...         ...
# 1607  올뉴아반떼          O   10000.0  9.0  노원구              1.0         1.0
# 1608  올뉴아반떼          O   10000.0  9.0  노원구              1.0         1.0
# 1609   더뉴레이          O   10000.0  9.0  노원구              1.0         1.0
# 1610  올뉴아반떼          O   10000.0  9.0  노원구              1.0         1.0
# 1611   더뉴레이          O   10000.0  9.0  노원구              1.0         1.0
#
#                 주차장 이름  km당 가격(최대)   주차장_이용률
# 0             광운대역 주차장       210.0  0.571429
# ...

# %%
import matplotlib.pyplot as plot
import matplotlib.pyplot as plt
import numpy as np
import os
if os.name == 'posix':

    plt.rc("font", family="AppleGothic")

else:

    plt.rc("font", family="Malgun Gothic")
CountStatus9 = pd.value_counts(nowon9['차량 이름'].values, sort=True) 
CountStatus9.plot.bar() 
CountStatus9.plot.bar(grid=True, figsize=(10,8), fontsize=15)
# Out:
# <AxesSubplot:>

# %%
nowon_12=(a['시간대']==9.0)
nowon12=a[nowon_12]
nowon12
# Out:
#       차량 이름 이용중인지(o,x)  차량 이용 가격  시간대   지역  주차장에서 이용중인 차 개수  주차장 내 차 개수  \
# 0       셀토스          X   10000.0  9.0  노원구              4.0         7.0
# 1     올뉴아반떼          O   10000.0  9.0  노원구              4.0         7.0
# 2        코나          X   10000.0  9.0  노원구              4.0         7.0
# 3      더뉴레이          X    8970.0  9.0  노원구              4.0         7.0
# 4      더뉴K3          O   10000.0  9.0  노원구              4.0         7.0
# ...     ...        ...       ...  ...  ...              ...         ...
# 1607  올뉴아반떼          O   10000.0  9.0  노원구              1.0         1.0
# 1608  올뉴아반떼          O   10000.0  9.0  노원구              1.0         1.0
# 1609   더뉴레이          O   10000.0  9.0  노원구              1.0         1.0
# 1610  올뉴아반떼          O   10000.0  9.0  노원구              1.0         1.0
# 1611   더뉴레이          O   10000.0  9.0  노원구              1.0         1.0
#
#                 주차장 이름  km당 가격(최대)   주차장_이용률
# 0             광운대역 주차장       210.0  0.571429
# ...

# %%
CountStatus12 = pd.value_counts(nowon12['차량 이름'].values, sort=True) 
CountStatus12.plot.bar() 
CountStatus12.plot.bar(grid=True, figsize=(10,8), fontsize=15)
# Out:
# <AxesSubplot:>

# %%
nowon_18=(dfnowon['시간대']==18.0)
nowon18=dfnowon[nowon_18]
nowon18
CountStatus18 = pd.value_counts(nowon18['차량 이름'].values, sort=True) 
CountStatus18.plot.bar() 
CountStatus18.plot.bar(grid=True, figsize=(10,8), fontsize=15)
# Out:
# <AxesSubplot:>

# %%
nowon_18=(a['시간대']==9.0)
nowon18=a[nowon_18]
nowon18
CountStatus18 = pd.value_counts(nowon18['차량 이름'].values, sort=True) 
CountStatus18.plot.bar() 
CountStatus18.plot.bar(grid=True, figsize=(10,8), fontsize=15)
# Out:
# <AxesSubplot:>

# %%
nowon_22=(a['시간대']==22.0)
nowon22=dfnowon[nowon_22]
nowon22
CountStatus22 = pd.value_counts(nowon22['차량 이름'].values, sort=True) 
CountStatus22.plot.bar() 
CountStatus22.plot.bar(grid=True, figsize=(10,8), fontsize=15)
# Out:
# <AxesSubplot:>

# %%
nowon_22=(dfnowon['시간대']==22.0)
nowon22=dfnowon[nowon_22]
nowon22
CountStatus22 = pd.value_counts(nowon22['차량 이름'].values, sort=True) 
CountStatus22.plot.bar() 
CountStatus22.plot.bar(grid=True, figsize=(10,8), fontsize=15)

# %%
gangnam=df[df_gangnam]
df_gangnam=(df.지역=='노원구')

# %%
df_gangnam
dfg=gangnam[df_gangnam]
# Out:
# <ipython-input-72-fa7d0421b17f>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfg=gangnam[df_gangnam]

# %%
dfg
# Out:
# Empty DataFrame
# Columns: [차량 이름, 이용중인지(o,x), 차량 이용 가격, 시간대, 지역, 주차장에서 이용중인 차 개수, 주차장 내 차 개수, 주차장 이름, km당 가격(최대), 주차장_이용률]
# Index: []

# %%
gangnam=df[df_gangnam]
df_gangnam=(df.지역=='강남구')
dfgang=gangnam[df_gangnam]
dfgang
# Out:
# <ipython-input-75-72c91e66aad5>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfgang=gangnam[df_gangnam]
#              차량 이름 이용중인지(o,x)  차량 이용 가격   시간대   지역  주차장에서 이용중인 차 개수  \
# 55          디 올뉴투싼          X   10000.0   9.0  강남구             10.0
# 56            더뉴K3          X   10000.0   9.0  강남구             10.0
# 57            더뉴레이          X   10000.0   9.0  강남구             10.0
# 58             셀토스          X   10000.0   9.0  강남구             10.0
# 59           올뉴아반떼          X   10000.0   9.0  강남구             10.0
# ...            ...        ...       ...   ...  ...              ...
# 1848  2021 쏘렌토 7인승          O   38980.0  22.0  강남구             17.0
# 1849      지프 레니게이드          O   38120.0  22.0  강남구             17.0
# 1850         미니클럽맨          O   34300.0  22.0  강남구             17.0
# 1851       2021 K5          O   32550.0  22.0  강남구             17.0
# 1852     아이오닉 일렉트릭          O   28880.0  22.0  강남구             17.0
#
# ...

# %%
gang_22=(dfgang['시간대']==22.0)
gang22=dfgang[gang_22]
gang22
CountStatus22 = pd.value_counts(gang22['차량 이름'].values, sort=True) 
CountStatus22.plot.bar() 
CountStatus22.plot.bar(grid=True, figsize=(10,8), fontsize=15)
# Out:
# <AxesSubplot:>

# %%
dfgang
# Out:
#              차량 이름 이용중인지(o,x)  차량 이용 가격   시간대   지역  주차장에서 이용중인 차 개수  \
# 55          디 올뉴투싼          X   10000.0   9.0  강남구             10.0
# 56            더뉴K3          X   10000.0   9.0  강남구             10.0
# 57            더뉴레이          X   10000.0   9.0  강남구             10.0
# 58             셀토스          X   10000.0   9.0  강남구             10.0
# 59           올뉴아반떼          X   10000.0   9.0  강남구             10.0
# ...            ...        ...       ...   ...  ...              ...
# 1848  2021 쏘렌토 7인승          O   38980.0  22.0  강남구             17.0
# 1849      지프 레니게이드          O   38120.0  22.0  강남구             17.0
# 1850         미니클럽맨          O   34300.0  22.0  강남구             17.0
# 1851       2021 K5          O   32550.0  22.0  강남구             17.0
# 1852     아이오닉 일렉트릭          O   28880.0  22.0  강남구             17.0
#
#       주차장 내 차 개수             주차장 이름  km당 가격(최대)  주차장_이용률
# 55          16.0  현대백화점 무역센터점 별관주차장       220.0    0.625
# ...

# %%
df_g_y=dfgang['이용중인지(o,x)']=='O'
df_gangnam_use_y = dfgang.loc[df_g_y, :]

# %%
df_gangnam_use_y
# Out:
#              차량 이름 이용중인지(o,x)  차량 이용 가격   시간대   지역  주차장에서 이용중인 차 개수  \
# 60             캐스퍼          O   10000.0   9.0  강남구             10.0
# 61             G80          O   91460.0   9.0  강남구             10.0
# 62         벤츠 C200          O   57880.0   9.0  강남구             10.0
# 63          더뉴 그렌저          O   45250.0   9.0  강남구             10.0
# 64           아이오닉5          O   44570.0   9.0  강남구             10.0
# ...            ...        ...       ...   ...  ...              ...
# 1848  2021 쏘렌토 7인승          O   38980.0  22.0  강남구             17.0
# 1849      지프 레니게이드          O   38120.0  22.0  강남구             17.0
# 1850         미니클럽맨          O   34300.0  22.0  강남구             17.0
# 1851       2021 K5          O   32550.0  22.0  강남구             17.0
# 1852     아이오닉 일렉트릭          O   28880.0  22.0  강남구             17.0
#
#       주차장 내 차 개수             주차장 이름  km당 가격(최대)  주차장_이용률
# 60          16.0  현대백화점 무역센터점 별관주차장       190.0    0.625
# ...

# %%
dfnowon
df_n_y=dfnowon['이용중인지(o,x)']=='O'
df_nowon_use_y = dfnowon.loc[df_n_y, :]

# %%
df_nowon_use_y
# Out:
#               차량 이름 이용중인지(o,x)  차량 이용 가격   시간대   지역  주차장에서 이용중인 차 개수  \
# 1             올뉴아반떼          O   10000.0   9.0  노원구              4.0
# 4              더뉴K3          O   10000.0   9.0  노원구              4.0
# 5               캐스퍼          O   10000.0   9.0  노원구              4.0
# 6            디 올뉴투싼          O   10000.0   9.0  노원구              4.0
# 7                코나          O   10000.0   9.0  노원구              3.0
# ...             ...        ...       ...   ...  ...              ...
# 1809  카니발 프레스티지 9인승          O   68010.0  22.0  노원구             11.0
# 1810         더뉴 그렌저          O   65330.0  22.0  노원구             11.0
# 1811        2021 K5          O   53750.0  22.0  노원구             11.0
# 1812           올뉴K3          O   10000.0  22.0  노원구             11.0
# 1813       스포티지 더볼드          O   10000.0  22.0  노원구             11.0
#
#       주차장 내 차 개수    주차장 이름  km당 가격(최대)   주차장_이용률
# 1            7.0  광운대역 주차장       200.0  0.571429
# ...

# %%
gang_12=(df_gangnam_use_y['시간대']==12.0)
gang12=df_gangnam_use_y[gang_12]
gang12
CountStatus12 = pd.value_counts(gang12['차량 이름'].values, sort=True) 
CountStatus12.plot.bar() 
CountStatus12.plot.bar(grid=True, figsize=(10,8), fontsize=15)
# Out:
# <AxesSubplot:>

# %%
nowon_9=(df_nowon_use_y['시간대']==9.0)
nowon9=df_nowon_use_y[nowon_9]
nowon9
CountStatus9 = pd.value_counts(nowon9['차량 이름'].values, sort=True) 
CountStatus9.plot.bar() 
CountStatus9.plot.bar(grid=True, figsize=(10,8), fontsize=15)
# Out:
# <AxesSubplot:>

# %%
gang_18=(df_gangnam_use_y['시간대']==18.0)
gang18=df_gangnam_use_y[gang_18]
gang18
CountStatus18 = pd.value_counts(gang18['차량 이름'].values, sort=True) 
CountStatus18.plot.bar() 
CountStatus18.plot.bar(grid=True, figsize=(10,8), fontsize=15)
# Out:
# <AxesSubplot:>

# %%
nowon_18=(a['시간대']==18.0)
nowon18=a[nowon_18]
nowon18
CountStatus18 = pd.value_counts(nowon18['차량 이름'].values, sort=True) 
CountStatus18.plot.bar() 
CountStatus18.plot.bar(grid=True, figsize=(10,8), fontsize=15)
# Out:
# <AxesSubplot:>

# %%
nowon_18=(a['시간대']==9.0)
nowon18=a[nowon_18]
nowon18
CountStatus18 = pd.value_counts(nowon18['차량 이름'].values, sort=True) 
CountStatus18.plot.bar() 
CountStatus18.plot.bar(grid=True, figsize=(10,8), fontsize=15)
# Out:
# <AxesSubplot:>
